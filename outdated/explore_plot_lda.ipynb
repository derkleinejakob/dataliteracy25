# %%
import pandas as pd 
from IPython.display import display
import textwrap
import json 
from gensim import corpora
from gensim.models.ldamulticore import LdaMulticore
from gensim.models.coherencemodel import CoherenceModel
from tqdm import tqdm
from collections import Counter
import numpy as np
from gensim.models import LdaModel
import matplotlib.pyplot as plt

from scripts.preprocessing.assign_lda_topics import assign_topics_

# %% [markdown]
# ## Explanation
#
# - input: df with lda-topic probabilities, lda model
# - enables manual inspection of topic labels
# - creates plots of yearly occurence of specified topics
# - option to save specific topic dataset

# %% [markdown]
# ### Import dataset and model

# %%
dataset_path = "data/parllaw/final.parquet"
corpus_path = "data/lda/corpus_final.c"

df = pd.read_parquet(dataset_path)
corpus = corpora.MmCorpus(corpus_path)

# %%
def load_model(n_topics=50, n_passes=5):
    try: 
        model_path = f"data/lda/screens/{n_topics}_topics/{n_passes}/model.model"
        model = LdaModel.load(model_path)
        return model
    except: 
        print("Could not find model", n_topics, n_passes)
        return None

# %% [markdown]
# ### Print top k=5 words of every topic to inspect LDA composition

# %%
def print_topics(model, n_topics, k_words=5):
    '''
    print all n topics of the lda model 
    '''
    for idx, topic in model.show_topics(formatted=False, num_topics=n_topics):
        label = ", ".join([word for word, prob in topic[:k_words]])
        print(f"Topic {idx}: {label}")

# %%
# print_topics(model, n_topics)

# %% [markdown]
# ### Explore topics by their ID

# %%
# plotting parameters
party_block_colors = {
    'left': 'purple',
    'green': 'green',
    'social_democratic': 'red',
    'christian_conservative': 'black',
    'liberal': 'orange',
    'right_populist': 'blue'
}
election_years = [2014, 2019] #[1999, 2004, 2009, 2014, 2019, 2024]

# %%
def find_topic_id(keyword, model, n_topics=50, top_n=10):
    """
    returns the topic id containing the keyword in its top_n words.
    if the keyword appears in multiple topics, returns the list of topic ids and prints a warning.
    """
    matches = []
    for idx, topic in model.show_topics(formatted=False, num_topics=n_topics, num_words=top_n):
        words = [word for word, prob in topic]
        if keyword in words:
            matches.append(idx)
    if not matches:
        return None
    if len(matches) > 1:
        print(f"Warning: keyword '{keyword}' found in multiple topics: {matches}")
        return matches
    return matches[0]

# %%
def plot_abs_numbers_over_time(topic_id, model, df=df):
    pass
    # TODO

# %%
def explore_topic_id(topic_id, model, df, n_topics, top_n_terms=10, speech_number=10, prob_threshold=0.3, log_scale=True, plot=True):
    '''
    Explore topic with id topic_id in LDA model and dataframe df.
    Prints top terms, number of speeches, top speeches, just passing speeches, and plots number and ratio of speeches per year and party block.
    Parameters:
    - topic_id: int, id of topic to explore
    - model: LdaModel, trained LDA model
    - df: pd.DataFrame, dataframe with speeches and topic probabilities
    - top_n_terms: int, number of top terms to print
    - speech_number: int, number of top and just passing speeches to print
    - prob_threshold: float, probability threshold to select speeches
    Returns:
    - df_selected_topic: pd.DataFrame, dataframe with speeches selected for the topic
    '''
    # define df_selected_topic
    df_selected_topic = df[df[f'topic_{topic_id}'] >= prob_threshold]

    # return first 10 words and their probabilities for topic of interest
    topic_terms = model.show_topic(topicid=topic_id, topn=top_n_terms)
    print(f"Topic {topic_id} terms:")
    for word, prob in topic_terms:
        print(f"  {word}: {prob:.4f}")
    # save first three words
    first_3_words = [word for word, prob in topic_terms[:3]]

    # number of speeches in topic
    n_speeches = df_selected_topic.shape[0]
    print(f"Number of speeches in topic {topic_id} ({first_3_words}) with prob >= {prob_threshold}): {n_speeches}")
    
    # return top speeches
    print(f"Top speeches for topic {topic_id} ({first_3_words}):\n")
    df_selected_topic_sorted_desc = df_selected_topic.sort_values(by=f"topic_{topic_id}", ascending=False)
    for i in range(speech_number):
        speech = df_selected_topic_sorted_desc.iloc[i]
        print(f"Speech {i+1} with topic probability {speech[f'topic_{topic_id}']:.4f}:")
        print(textwrap.fill(speech["translatedText"], width=80))
        print("\n" + "-"*80 + "\n")

    # return speeches just above threshold
    print(f"Just passing speeches for topic {topic_id} ({first_3_words}):\n")
    df_selected_topic_sorted = df_selected_topic.sort_values(by=f"topic_{topic_id}")
    for i in range(speech_number):
        speech = df_selected_topic_sorted.iloc[i]
        print(f"Speech {i+1} with topic probability {speech[f'topic_{topic_id}']:.4f}:")
        print(textwrap.fill(speech["translatedText"], width=80))
        print("\n" + "-"*80 + "\n")

    # plot 
    # plots: number and ratio of speeches per year and party block
    if plot: 
        party_blocks = df_selected_topic['block'].unique()
        years = sorted(df_selected_topic['year'].unique())
        fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8), sharex=True)
        for party_block in party_blocks:
            counts_per_year = []
            normalized_counts_per_year = []
            for year in years:
                count = df_selected_topic[(df_selected_topic['block'] == party_block) & (df_selected_topic['year'] == year)].shape[0]
                counts_per_year.append(count)
                total_count = df[(df['block'] == party_block) & (df['year'] == year)].shape[0]
                normalized_count = count / total_count if total_count > 0 else 0
                normalized_counts_per_year.append(normalized_count)
            ax1.plot(years, counts_per_year, label=party_block, marker='o', color=party_block_colors.get(party_block))
            if log_scale: 
                ax1.set_yscale("log")
            ax2.plot(years, normalized_counts_per_year, label=party_block, marker='o', color=party_block_colors.get(party_block))
        for year in election_years:
            ax1.axvline(x=year, color='gray', linestyle='-', alpha=0.5)
            ax2.axvline(x=year, color='gray', linestyle='-', alpha=0.5)
        ax1.set_xticks(election_years)
        ax2.set_xticks(election_years)
        # add horizontal grid lines
        ax1.yaxis.grid(True, linestyle='-', color='gray', alpha=0.5)
        ax2.yaxis.grid(True, linestyle='-', color='gray', alpha=0.5)
        ax1.set_title(f"Number of speeches per year for topic {topic_id} ({first_3_words}) [{n_topics}]")
        ax1.set_ylabel("Number of speeches")
        ax1.legend()
        ax2.set_title(f"Ratio of speeches per year for topic {topic_id} ({first_3_words})")
        ax2.set_ylabel("Ratio of speeches")
        ax2.set_xlabel("Year")
        ax2.legend()
        plt.tight_layout()
        plt.show()    

    return df_selected_topic

# %%
def combined_ratio_plot(topic_id_list, model, df = df, prob_threshold=0.3):
    '''
    plots ratio of speeches per party over the years for each topic in topic_id_list
    Parameters:
    - topic_id_list: list of int, list of topic ids to plot
    - model: LdaModel, trained LDA model
    - df_topics: pd.DataFrame, dataframe with speeches and topic probabilities
    - prob_threshold: float, probability threshold to select speeches
    '''
    # plot ratio of speeches per party over the years for each topic in topic_id_list
    n_topics = len(topic_id_list)
    ncols = 2
    nrows = (n_topics + ncols - 1) // ncols
    fig, axes = plt.subplots(nrows, ncols, figsize=(15, 5 * nrows), sharex=True)
    
    # flatten axes to iterate easily (handles case nrows==1 or >1)
    axes = np.array(axes).reshape(-1)
    
    party_blocks = sorted(df['party_block'].unique())
    years = sorted(df['year'].unique())
    
    for ax, topic_id in zip(axes, topic_id_list):
        for party_block in party_blocks:
            normalized_counts_per_year = []
            for year in years:
                df_selected_topic = df[
                    (df[f'topic_{topic_id}'] >= prob_threshold) &
                    (df['party_block'] == party_block) &
                    (df['year'] == year)
                ]
                count = df_selected_topic.shape[0]
                total_count = df[
                    (df['party_block'] == party_block) &
                    (df['year'] == year)
                ].shape[0]
                normalized_count = count / total_count if total_count > 0 else 0
                normalized_counts_per_year.append(normalized_count)
            ax.plot(years, normalized_counts_per_year, label=party_block,
                    marker='o', color=party_block_colors.get(party_block, 'gray'))
            ax.set_xticks(range(election_years[0], election_years[-1]+1))
            ax.set_xticklabels([str(y) for y in election_years])
            # ensure ticks/labels are shown for every subplot (even when sharex=True)
            ax.tick_params(axis='x', which='both', bottom=True, top=False, labelbottom=True)
            ax.xaxis.set_visible(True)
            for year in election_years:
                ax.axvline(x=year, color='gray', linestyle='-', alpha=0.5)
            ax.yaxis.grid(True, linestyle='-', color='gray', alpha=0.5)
            first_words = [word for word, prob in model.show_topic(topicid=topic_id, topn=4)]
            ax.set_title(f"Topic {topic_id} {first_words}", fontsize=12)
            idx = list(axes).index(ax)
            if idx % ncols == 0:
                ax.set_ylabel("Ratio of speeches")
            ax.spines['right'].set_visible(False)
            ax.spines['top'].set_visible(False)

    # turn off any unused subplots
    for ax in axes[len(topic_id_list):]:
        ax.axis('off')
    
    # place legend in the first subplot (upper left)
    if len(axes) > 0:
        axes[0].legend(loc='upper left', fontsize = 12)
    
    plt.suptitle(f"Ratio of speeches about {n_topics} selected topics over time", fontsize=16, fontweight='bold')
    plt.tight_layout()
    plt.show()

# %%
models = dict() 
dfs = dict() 
migration_topics = dict()

# %%
for n_topics in [10, 20, 25, 30, 40, 50, 60, 80, 100]: 
    for n_passes in [5, 10, 20, 30]: 
        print(n_topics, "|", n_passes) 
        model = load_model(n_topics=n_topics, n_passes=n_passes)
        if model is None: 
            continue

        identified_topics = find_topic_id("migration", model, n_topics)

        if identified_topics is None: 
            print("No relevant topic!", n_topics, n_passes)
            continue
        if isinstance(identified_topics, list): 
            print("Found more than one relevant topic", n_topics, n_passes)
            print("Skipping")
            continue

        df_topic = assign_topics_(df, model, n_topics, corpus)
        
        models[(n_topics, n_passes)] = model 
        dfs[(n_topics, n_passes)] = df_topic
        migration_topics[(n_topics, n_passes)] = identified_topics
# Out:
# 10 | 5
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:27<00:00, 8769.13it/s]
# 10 | 10
# Could not find model 10 10
# 10 | 20
# Could not find model 10 20
# 10 | 30
# Could not find model 10 30
# 20 | 5
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:28<00:00, 8349.51it/s]
# 20 | 10
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:30<00:00, 7815.69it/s]
# 20 | 20
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:28<00:00, 8253.40it/s]
# 20 | 30
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:27<00:00, 8630.80it/s]
# 25 | 5
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:30<00:00, 7873.80it/s]
# 25 | 10
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:28<00:00, 8320.25it/s]
# 25 | 20
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:27<00:00, 8499.55it/s]
# 25 | 30
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:27<00:00, 8588.52it/s]
# 30 | 5
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:32<00:00, 7321.02it/s]
# 30 | 10
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:30<00:00, 7796.75it/s]
# 30 | 20
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:28<00:00, 8425.19it/s]
# 30 | 30
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:29<00:00, 8064.12it/s]
# 40 | 5
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:33<00:00, 7173.84it/s]
# 40 | 10
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:30<00:00, 7864.87it/s]
# 40 | 20
# Could not find model 40 20
# 40 | 30
# Could not find model 40 30
# 50 | 5
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:32<00:00, 7236.37it/s]
# 50 | 10
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:32<00:00, 7341.05it/s]
# 50 | 20
# Could not find model 50 20
# 50 | 30
# Could not find model 50 30
# 60 | 5
# Warning: keyword 'migration' found in multiple topics: [9, 34]
# Found more than one relevant topic 60 5
# Skipping
# 60 | 10
# Warning: keyword 'migration' found in multiple topics: [30, 58]
# Found more than one relevant topic 60 10
# Skipping
# 60 | 20
# Could not find model 60 20
# 60 | 30
# Could not find model 60 30
# 80 | 5
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:38<00:00, 6114.54it/s]
# 80 | 10
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:37<00:00, 6381.23it/s]
# 80 | 20
# Could not find model 80 20
# 80 | 30
# Could not find model 80 30
# 100 | 5
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:41<00:00, 5662.28it/s]
# 100 | 10
# Assigning most probable topic to each speech: 100%|██████████| 236812/236812 [00:40<00:00, 5805.47it/s]
# 100 | 20
# Could not find model 100 20
# 100 | 30
# Could not find model 100 30

# %%
for n_topics in [10, 20, 25, 30, 40, 50, 60, 80, 100]: 
    for n_passes in [5, 10, 20, 30]: 
        config = (n_topics, n_passes)
        if not config in models:
            continue 

        print(n_topics, "|", n_passes)
        print_topics(models[config], n_topics)
        print("="*150)
# Out:
# 10 | 5
# Topic 0: market, regulation, proposal, worker, favor
# Topic 1: fishing, fishery, farmer, water, sector
# Topic 2: tax, development, datum, information, security
# Topic 3: budget, financial, agency, committee, discharge
# Topic 4: fund, crisis, refugee, million, situation
# Topic 5: government, want, today, political, turkey
# Topic 6: agreement, trade, cooperation, international, relation
# Topic 7: energy, climate, emission, industry, gas
# Topic 8: want, social, think, economic, commissioner
# Topic 9: woman, child, human, law, convention
# ======================================================================================================================================================
# 20 | 5
# Topic 0: digital, service, datum, internet, access
# Topic 1: market, development, sector, economic, level
# Topic 2: refugee, border, migration, asylum, migrant
# Topic 3: ukraine, russia, russian, moldova, war
# Topic 4: woman, gender, equality, violence, man
# Topic 5: human, freedom, law, democracy, government
# Topic 6: child, victim, family, human, life
# Topic 7: transport, good, road, thank, rapporteur
# Topic 8: energy, climate, farmer, production, food
# Topic 9: development, crisis, aid, fund, million
# Topic 10: product, health, regulation, food, animal
# Topic 11: fund, economic, investment, social, job
# Topic 12: security, china, defense, cooperation, united
# Topic 13: budget, financial, council, proposal, discharge
# Topic 14: agreement, trade, convention, international, protocol
# Topic 15: turkey, resolution, peace, conflict, terrorist
# Topic 16: want, think, say, today, colleague
# Topic 17: tax, company, money, fraud, evasion
# Topic 18: legal, law, court, cooperation, datum
# Topic 19: worker, young, emission, air, health
# ======================================================================================================================================================
# 20 | 10
# Topic 0: agreement, trade, fishing, republic, economic
# Topic 1: woman, human, gender, equality, violence
# Topic 2: climate, world, uk, let, change
# Topic 3: want, think, colleague, commissioner, say
# Topic 4: refugee, border, migration, migrant, asylum
# Topic 5: product, food, agricultural, farmer, animal
# Topic 6: market, transport, sector, service, consumer
# Topic 7: health, substance, disease, medicine, risk
# Topic 8: worker, fund, datum, company, labor
# Topic 9: child, convention, international, legal, protection
# Topic 10: law, freedom, turkey, human, government
# Topic 11: regulation, council, financial, proposal, budget
# Topic 12: principle, law, institution, rule, committee
# Topic 13: resolution, political, election, group, party
# Topic 14: fund, energy, budget, development, resource
# Topic 15: tax, money, company, fraud, fight
# Topic 16: ukraine, russia, war, conflict, peace
# Topic 17: cooperation, security, development, strengthen, fight
# Topic 18: economic, investment, crisis, growth, financial
# Topic 19: social, education, young, employment, poverty
# ======================================================================================================================================================
# 20 | 20
# Topic 0: ukraine, russia, russian, war, security
# Topic 1: region, water, disaster, solidarity, ireland
# Topic 2: agreement, trade, fishing, protocol, fishery
# Topic 3: committee, resolution, council, agency, institution
# Topic 4: human, resolution, situation, political, peace
# Topic 5: economic, social, investment, growth, development
# Topic 6: today, let, want, world, freedom
# Topic 7: child, international, convention, humanitarian, conflict
# Topic 8: product, food, agricultural, farmer, animal
# Topic 9: tax, company, financial, bank, euro
# Topic 10: health, substance, risk, use, disease
# Topic 11: regulation, market, proposal, directive, protection
# Topic 41: road, vehicle, safety, traffic, drive
# Topic 42: euro, central, rate, monetary, economic
# Topic 43: united, peace, nations, international, un
# Topic 44: package, substance, railway, passenger, rail
# Topic 45: trade, agreement, free, negotiation, tariff
# Topic 46: leave, fruit, insurance, consumption, pension
# Topic 47: resolution, favor, proposal, amendment, text
# Topic 48: death, penalty, iran, saudi, arabia
# Topic 49: agent, prize, award, prison, guinea
# Topic 50: humanitarian, aid, thousand, war, million
# Topic 51: family, eye, catch, card, life
# Topic 52: election, political, democratic, party, democracy
# Topic 53: child, convention, international, abduction, minor
# Topic 54: area, city, population, rural, old
# Topic 55: development, strategy, goal, achieve, objective
# Topic 56: industry, china, steel, production, material
# Topic 57: clear, good, forward, colleague, future
# Topic 58: israel, gaza, palestinian, peace, solution
# Topic 59: food, agricultural, farmer, product, sector
# Topic 60: spain, socialist, spanish, government, ukip
# Topic 61: budget, billion, euro, million, payment
# Topic 62: text, abstain, national, principle, oppose
# Topic 63: court, legal, justice, request, immunity
# Topic 64: council, decision, issue, treaty, possible
# Topic 65: conflict, situation, security, political, international
# Topic 66: anti, troika, intelligence, hate, hatred
# Topic 67: juncker, want, promise, buy, choice
# Topic 68: climate, change, green, global, paris
# Topic 69: read, truth, book, kyoto, reading
# Topic 70: worker, adjustment, fund, solidarity, disaster
# Topic 71: romania, bulgaria, schengen, austria, lithuania
# Topic 72: border, cross, external, control, schengen
# Topic 73: agreement, protocol, cooperation, association, republic
# Topic 74: sanction, export, oil, regime, impose
# Topic 75: reform, public, tunisia, austerity, debt
# Topic 76: ukraine, russia, russian, ukrainian, war
# Topic 77: program, research, programme, horizon, funding
# Topic 78: refugee, migration, migrant, asylum, immigration
# Topic 79: fishing, fishery, sea, fish, stock
# Topic 80: woman, gender, equality, man, equal
# Topic 81: crime, cooperation, fight, terrorism, exchange
# Topic 82: law, rule, respect, principle, value
# Topic 83: bosnia, herzegovina, sweden, denmark, slovenia
# Topic 84: minister, prime, presidency, republic, language
# Topic 85: emission, air, reduce, pollution, reduction
# Topic 86: cultural, culture, heritage, diversity, creative
# Topic 87: land, american, america, latin, brazil
# Topic 88: energy, gas, renewable, efficiency, price
# Topic 89: visa, travel, stay, short, day
# Topic 90: company, pay, profit, multinational, large
# Topic 91: ms, der, von, leyen, mrs
# Topic 92: animal, welfare, ban, breeding, breed
# Topic 93: debate, issue, topic, group, discuss
# Topic 94: crisis, face, situation, economic, term
# Topic 95: power, percent, nuclear, conference, plant
# Topic 96: waste, fire, plastic, georgia, circular
# Topic 97: health, disease, medicine, patient, virus
# Topic 98: united, states, uk, ireland, british
# Topic 99: forest, biodiversity, authorization, tobacco, specie
# ======================================================================================================================================================

# %% [markdown]
# Taking into account coherence, manual inspection of topic labels, number of speeches, we find the model with 30 topics and 10 speeches the best.

# %%
# n_topics = 40
dfs_migration = dict()
for n_topics in [10, 20, 25, 30, 40, 50, 60, 80, 100]: 
    for n_passes in [5, 10, 20, 30]: 
        config = (n_topics, n_passes)
        if not config in models:
            continue 

        model = models[config]
        df_topic = dfs[config]
        migration_topic_id = migration_topics[config]

        print("n_topics:", n_topics,"n_passes", n_passes)
        
        df_migration = explore_topic_id(migration_topic_id, model, df_topic, config, speech_number=1, plot=False)
        print("="*150)
        dfs_migration[config] = df_migration
# Out:
# n_topics: 10 n_passes 5
# Topic 4 terms:
#   fund: 0.0168
#   crisis: 0.0134
#   refugee: 0.0110
#   million: 0.0099
#   situation: 0.0088
#   region: 0.0087
#   border: 0.0080
#   aid: 0.0077
#   migration: 0.0072
#   solidarity: 0.0070
# Number of speeches in topic 4 (['fund', 'crisis', 'refugee']) with prob >= 0.3): 26574
# Top speeches for topic 4 (['fund', 'crisis', 'refugee']):
#
# Speech 1 with topic probability 0.9917:
# I welcome the budget changes that seek to strengthen the EU's financial
# resources and capacities for solving the refugee and migration crisis, above all
# the increase in aid under the Asylum, Migration and Integration Fund and the
# Internal Security Fund, as well as the proposal to hire new staff at Frontex.
# Support for the use of flexibility provisions is also commendable. There are two
# fundamental prerequisites for the EU's successful action in relation to the
# refugee crisis: combining humanitarian and preventive measures with a much more
# complex approach to solving the main causes of the crisis itself, and providing
# assistance and stabilization to transit countries and countries of origin.
# Croatia can serve as an example of good practice in dealing with the refugee
# crisis by acting humanely and in solidarity, even when faced with border
# militarization and barbed wire in the immediate neighborhood. However, Croatia
# cannot deal with this problem alone until the political decision of all members
# is adopted and as long as only five EU members accept around 70% of refugees,
# until the principle of placing the blame and burden on others is replaced by the
# principle of solidarity support and help. In this sense, I welcome efforts to
# present a longer-term and more financially generous aid plan to countries of
# origin and transit countries so that closing borders, ignoring problems and
# repressive actions cannot be justified by a lack of resources.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 4 (['fund', 'crisis', 'refugee']):
#
# Speech 1 with topic probability 0.3000:
# I am glad to note that the request by the Belgian authorities to mobilise funds
# under the European Globalisation Adjustment Fund  has met all the eligible
# criteria laid down in the EGF Regulation. Regretfully, the redundancies are
# expected to have a huge negative impact on the region. The region is already
# facing a very difficult labour market situation due to its over-reliance on
# traditional industrial employment and lack of new industries. The report
# stresses that in this particular environment, it is important that the
# coordinated package of personalised services improves the employability of all
# the workers by being adapted not only to the needs of the dismissed workers, but
# also to the actual business environment of the region. I am also glad to note
# that this report also highlights the need for the future use of the provisions
# of the EGF Regulation to support young people not in employment, education or
# training  in this region. I believe that the emphasis on the employability of
# young people in the region is essential for a healthy and prosperous economic
# future of this region.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 20 n_passes 5
# Topic 2 terms:
#   refugee: 0.0274
#   border: 0.0269
#   migration: 0.0183
#   asylum: 0.0156
#   migrant: 0.0152
#   greece: 0.0138
#   immigration: 0.0085
#   greek: 0.0084
#   crisis: 0.0081
#   problem: 0.0079
# Number of speeches in topic 2 (['refugee', 'border', 'migration']) with prob >= 0.3): 8596
# Top speeches for topic 2 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.9888:
# The current refugee crisis has shown that our migration system is not suited to
# today’s realities anymore. We need a collective European response to resolve the
# current disastrous humanitarian situation and lay the ground for a better future
# system. While the resolution goes proposes positive steps, some elements are
# still contradictory and some measures proposed not acceptable in the current
# situation. I could not support a relocation scheme for refugees. I remain
# convinced that such schemes are not the correct way to deal with the migration
# crisis. This is one of the main reasons why I voted against it. There is no
# doubt that we need to rethink the Dublin regulation and the all migration system
# on our continent. However, establishing a central collective system for
# distribution of applicants would be ineffective as long as the EU’s external
# borders are not secured and migration flows is not effectively managed. A strong
# European Border and Coast Guard is an essential measure in this respect. It is
# only once this is done that we can progressively establish a new EU Asylum
# system, based on a fair sharing of responsibility between Member States.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 2 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.3000:
# I have put my voice down. The report has many positive proposals to combat human
# trafficking. Gender aspects are included and this shows a clear link between
# prostitution and human trafficking. The problem is the support in the text for
# the Fort Europe policy. The EU's inhumane and increasingly restrictive refugee
# and migration policy appears in several places in the report. The work against
# human trafficking is even used as an excuse for cooperation with dictatorships
# within the framework of the Khartoum process and to legitimize the EU's military
# efforts in the Mediterranean (EU Med Nav For). This is not acceptable. What is
# needed is to counteract the demand, criminalize the purchase of sex, oppose the
# sex industry that makes huge profits at the expense of vulnerable women, and
# above all create safe and legal routes into the EU so that women do not become
# victims of human trafficking. That's why I put my voice down.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 20 n_passes 10
# Topic 4 terms:
#   refugee: 0.0220
#   border: 0.0199
#   migration: 0.0132
#   migrant: 0.0111
#   asylum: 0.0109
#   solidarity: 0.0080
#   crisis: 0.0070
#   immigration: 0.0060
#   schengen: 0.0055
#   problem: 0.0055
# Number of speeches in topic 4 (['refugee', 'border', 'migration']) with prob >= 0.3): 12242
# Top speeches for topic 4 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.9901:
# Mr President, ladies and gentlemen, today in this House we are discussing
# whether to expand and strengthen Schengen, and therefore whether to allow the
# free movement of people within the European Union without any type of border
# controls. Instead, I clearly say that border controls must be carried out, or
# rather I say more: the borders must be closed, because in recent years it has
# been Islamic terrorists who have circulated freely in Europe. Or have you
# forgotten about the attacks in Paris, Brussels, Nice, London, Barcelona? Have
# you forgotten about the hundreds of people who died due to murderous fanaticism,
# due to Islamic terrorism? This boy is Luca Russo, or rather he was Luca Russo.
# He was 25 years old, he was an engineer, he lived in Bassano del Grappa, a few
# kilometers from my house. On August 17 he was in Barcelona with his girlfriend
# Marta. Marta came back injured, he died. Luca Russo's family begged me to never
# forget this boy. Luca Russo's friends asked me to do everything to block these
# bastards! To intervene to stop this Islamic terrorism. I address this plea to
# you: we must stop these terrorists, we must stop Islamic terrorism, the
# invasion, the immigrants who are arriving. We have to control the borders.
# Schengen must be suspended, you must rethink Schengen, we must block the
# borders, we must stop this invasion. Minutes of silence are no longer enough,
# demonstrations are no longer enough: a rethink of Schengen is needed.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 4 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.3001:
# Through the draft amending budget no. 5/2015, the three European agencies
# FRONTEX, EASO and EUROPOL as well as the Asylum, Migration and Integration Fund
# and the Internal Security Fund will receive extra allocations for migration
# management following the increase in the size of refugee flows towards the
# European Union. I decided to vote in favor of this increase in resources, even
# though it does not correspond to actual needs and is not enough on its own to
# face the current migratory challenges and the worrying deterioration of the
# crisis in the Mediterranean.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 20 n_passes 20
# Topic 18 terms:
#   refugee: 0.0354
#   border: 0.0338
#   migration: 0.0246
#   migrant: 0.0172
#   crisis: 0.0167
#   asylum: 0.0164
#   immigration: 0.0092
#   problem: 0.0090
#   schengen: 0.0088
#   solidarity: 0.0087
# Number of speeches in topic 18 (['refugee', 'border', 'migration']) with prob >= 0.3): 7985
# Top speeches for topic 18 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.9888:
# In order to secure free movement within Europe, a strong external border is
# needed. In the migration crisis experienced a few years ago, we saw that not all
# member countries were able to ensure the operation of their external borders due
# to the heavy pressure of immigrants. Strengthening Frontex, the EU's border and
# maritime agency, by establishing a permanent force of 10,000 border and maritime
# guards by 2027 is an essential step towards a sustainable external border.
# Although each member country will continue to be responsible for its own
# external border, it is important that, if necessary, it can ask for help from
# the rapid action reserve, which is supposed to assist in possible problem
# situations. This is essential for a country like my home country, Finland,
# because we are responsible for more than a thousand kilometers of the EU's
# external border. With the reform, the agency should also be able to support
# member countries in returning applicants who have received negative asylum
# decisions by identifying persons staying illegally in the EU and assisting
# member countries in obtaining travel documents. This kind of help will certainly
# be needed in member countries, which face a greater pressure to move than
# others. EU-wide coordination is needed.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 18 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.3001:
# Mr President, ladies and gentlemen, Europe, after a very long absence, is now
# making some progress and we ask that the Member States, the Commission and the
# Council commit very quickly to keeping their promises. But for a long time, I
# was saying, my country, Italy, was left alone, that country criticized here for
# a miserable and obvious remnant of an electoral campaign, here in Europe, for
# Italy. Alone we did the search, the reception, the rescue. Far from talking
# about business: those thousands of citizens, those associations, those
# volunteers, mostly Catholic, those local authorities who have been able to
# welcome are offended. We have also done all the work on the countries of transit
# and origin, with laborious agreements; we have proudly dictated the agenda in
# Europe for migration policy, addressing the emergency and going back to the
# causes. The Migration Compact, the plan for Africa and the Juncker plan exist
# because some country asked for them; we worked for the reform of Dublin, rather
# than making a few shots and then leaving. Here, day by day, in commissions and
# in daily relationships with colleagues, we have achieved some things. And let me
# say one last word, President, with a little generosity as you did with my
# colleague Brok. I have even heard Christian values evoked to select who to let
# in and who not. Now, I am Christian, and religion has taught me openness and
# acceptance, not rejection and perhaps hatred for those who are different.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 20 n_passes 30
# Topic 0 terms:
#   agreement: 0.0251
#   border: 0.0224
#   refugee: 0.0211
#   turkey: 0.0201
#   migration: 0.0158
#   republic: 0.0149
#   accession: 0.0140
#   asylum: 0.0126
#   migrant: 0.0122
#   visa: 0.0120
# Number of speeches in topic 0 (['agreement', 'border', 'refugee']) with prob >= 0.3): 12070
# Top speeches for topic 0 (['agreement', 'border', 'refugee']):
#
# Speech 1 with topic probability 0.9892:
# I support the agreement between the European Union and the Republic of Trinidad
# and Tobago on exemption from the obligation to have a short-term visa. I welcome
# the further development of friendly relations between the European Union and the
# Republic of Trinidad and Tobago. I am glad that the abolition of visas covers
# all categories of persons wishing to facilitate travel and short-term stay
# without a visa, for a maximum of 90 days in any period within 180 days from the
# day of the first recorded entry. The agreement allows citizens of the European
# Union and citizens of the Republic of Trinidad and Tobago to stay without a visa
# in the territory of the other contracting party. This provides numerous
# opportunities not only for citizens of the Republic of Trinidad and Tobago, but
# also for citizens of the EU through new business opportunities and facilitation
# of travel. Due to the close relationship between the European Union and Norway,
# Iceland, Switzerland and Liechtenstein, especially on the basis of the agreement
# on the association of the aforementioned countries in the implementation,
# application and development of the Schengen acquis, I invite the aforementioned
# countries to conclude bilateral agreements on the abolition of visas with the
# Republic of Trinidad and Tobago for short-term stays which would contain
# provisions as in this agreement.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 0 (['agreement', 'border', 'refugee']):
#
# Speech 1 with topic probability 0.3001:
# Madam President, to begin with the obvious, the European Union, each Member
# State, everyone acting on their behalf need to comply with fundamental rights
# obligation. At the same time, they are also by national, European and
# international law obliged to protect borders and to fight criminal networks,
# smuggling and exploiting the most vulnerable ones. Even more so when these
# networks are state sponsored – an instrument like migratory flows – like done by
# Erdogan or Lukashenko. In this sense, this obligation is even more crucial when
# we speak about European borders, because then Schengen and our four freedoms
# rely on that. No doubt it is a sensitive balance, and we witnessed just
# yesterday in plenary a government that does not live up to our expectations. But
# there are other Member States working together smoothly with European support,
# answering hybrid attacks together, cooperating with the Commission on alleged
# cases. And because it is a sensitive balance, we need to make a few things
# clear. Let’s not expect from our officers, European or national, land or sea
# border, to first open up a legal review of complex questions when acting on our
# behalf. The principle of non—refoulement is, of course, to be respected, but
# neither does it mean that access to a procedure can be practically applied at
# every inch of the border, nor does it mean that everyone asking for protection
# is eligible for that. And see, and this is the key. It is on us finding the
# right balance politically, legally and enforceable under difficult
# circumstances. Half-way to that is a pact screening border procedure, the crisis
# mechanism which prepares us better. The second part is the upcoming revision of
# the Schengen Border Code. But the need for better coordination – measures to
# prevent manipulated crossings – instruments to trigger in critical situations.
# We are the ones that need to be in the driving seat of any orderly management,
# not dictators threatening the stability of the Union.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 25 n_passes 5
# Topic 22 terms:
#   refugee: 0.0251
#   crisis: 0.0163
#   migration: 0.0155
#   solidarity: 0.0140
#   asylum: 0.0126
#   migrant: 0.0120
#   border: 0.0091
#   health: 0.0085
#   situation: 0.0083
#   emergency: 0.0071
# Number of speeches in topic 22 (['refugee', 'crisis', 'migration']) with prob >= 0.3): 11796
# Top speeches for topic 22 (['refugee', 'crisis', 'migration']):
#
# Speech 1 with topic probability 0.9908:
# I voted for this report in which the European Parliament discusses the emergency
# situation in Sweden due to the sudden influx of third-country nationals into its
# territory. Due to the significant increase in the number of illegal border
# crossings into the European Union and the secondary movement in Europe, the
# number of persons applying for international protection in Sweden has increased
# significantly. in 2015 Sweden registered the highest number of applicants for
# international protection per capita in the EU (11,503 applicants per million
# inhabitants); until 2016 March. a total of 170,104 applicants arrived in Sweden,
# of which 73,331 are children, including 36,181 unaccompanied minors. Thus, the
# situation in Sweden has also become complicated due to the recent large increase
# in the number of unaccompanied minors (one in four applicants claims to be an
# unaccompanied minor). The described situation has made the Swedish asylum system
# very difficult and has had serious practical consequences in terms of reception
# conditions and the asylum system's ability to process applications. The current
# migration situation in Sweden is therefore a particular one in the European
# Union and given the pressure on its ability to process applications for
# international protection and to provide adequate reception conditions for
# persons in clear need of international protection, it is necessary to suspend
# Sweden's obligations under the relocation mechanism and to provide operational
# assistance where appropriate.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 22 (['refugee', 'crisis', 'migration']):
#
# Speech 1 with topic probability 0.3000:
# The proposal aims to introduce a standard European travel document for the
# return of non-European nationals in an irregular situation within the Member
# States of the Union and without a passport or identity card. This measure, which
# should have received the approval of any National Front MP, in fact constitutes
# a new element towards the establishment of a common policy on asylum and
# immigration, which we refuse for obvious reasons of sovereignty. It is up to the
# Member States, and them alone, to determine the guidelines and modalities of
# their immigration policy. A country like France must be perfectly capable of
# determining the format of the document necessary for the return of illegal
# migrants. I therefore voted against this report.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 25 n_passes 10
# Topic 17 terms:
#   border: 0.0478
#   refugee: 0.0305
#   migration: 0.0244
#   migrant: 0.0196
#   asylum: 0.0188
#   immigration: 0.0116
#   schengen: 0.0106
#   cross: 0.0093
#   illegal: 0.0092
#   control: 0.0080
# Number of speeches in topic 17 (['border', 'refugee', 'migration']) with prob >= 0.3): 6955
# Top speeches for topic 17 (['border', 'refugee', 'migration']):
#
# Speech 1 with topic probability 0.9832:
# This text concerns the establishment of a European Union border control system,
# bringing together the former European agency Frontex and national border
# management authorities. Officially, national authorities will continue to manage
# their borders on a day-to-day basis but, if their external EU borders are under
# pressure, they can seek help from the European Coast and Border Guard Agency.
# This project is designed to save Schengen and strengthens the EU's grip on the
# management of member states' borders. It therefore undermines what remains of
# their sovereignty. It is presented as a miracle solution to the problem of
# uncontrolled immigration, although it will not solve anything as long as the EU
# refuses to apply a responsible policy like that of the Australian government.
# Also, I voted against this text.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 17 (['border', 'refugee', 'migration']):
#
# Speech 1 with topic probability 0.3001:
# Corona in the Schengen area. Only three months ago, we discussed here how
# important it is to coordinate travel restrictions at a European level and to
# preserve the Schengen area. But the patchwork of border closures we saw back
# then has now become an almost impenetrable labyrinth. A labyrinth of green,
# yellow, and red zones, unjustified measures, inconsistent criteria, where the
# same region is classified by one state as a yellow region and by another as a
# green region. Therefore, I urgently call on the Council: Standardise these
# criteria and measures! Create the security and trust that our citizens and also
# our economy need at this time! I expect common solutions for common challenges
# and, under no circumstances, another wave of national solo efforts that will
# ultimately harm everyone.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 25 n_passes 20
# Topic 7 terms:
#   refugee: 0.0364
#   border: 0.0332
#   migration: 0.0256
#   migrant: 0.0174
#   asylum: 0.0168
#   crisis: 0.0151
#   uk: 0.0100
#   immigration: 0.0088
#   solidarity: 0.0080
#   external: 0.0079
# Number of speeches in topic 7 (['refugee', 'border', 'migration']) with prob >= 0.3): 7794
# Top speeches for topic 7 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.9819:
# Mr President, I maintain that a migrant is not a criminal. If he leaves his
# homeland, it is because he has good reasons to do so! This is why the President
# of the Commission is entirely right to oppose the Council, which once again
# refuses to open legal immigration routes to Europe. Indeed, it is only by
# accepting more legal immigration to Europe that we will avoid the
# intensification of illegal immigration and the deaths of people who migrate in
# impossible conditions. European solidarity is not about sending a few border
# guards on a cruise in the Mediterranean. European solidarity means welcoming
# refugees and migrants, who do not migrate because they like it, but because they
# have to, because their lives and the future of their families are in danger.
# Half the continent cannot continue to act as if immigration does not concern
# them! The quota policy is an urgent and absolute necessity.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 7 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.3000:
# Mr President, ladies and gentlemen, with the September Council the real work
# began and now it must be implemented very concretely, very quickly: hotspots,
# identification, rapid examination of applications, relocation and repatriations
# must work together because all this is connected. We need effective European
# leadership that respects the rights and humanity of people so full of suffering.
# President Juncker, I have no questions for now. Thank you for the determination,
# the conviction with which you acted, please continue. We ask President Tusk with
# much respect, but without discounting him for the high responsibility he has,
# for a more decisive and incisive role to convince the entire Council that you
# lead to that responsibility and that solidarity - You spoke about it in your
# speech - which however hasn't happened and it's up to you to make the Council
# take steps forward. I must say, I didn't like a certain Solomonic tone of your
# speech in which you distributed a bit of responsibility here and there and put
# countries like Italy and Greece on the same level with countries that I won't
# mention, but who raise walls, make laws that give three to five years in prison
# for those they find and do not give a good example of the Europe that you
# rightly defended at the UN. So I ask you, as we hear about Italy's
# responsibilities, between Schengen and life we have chosen to save and not
# remain with our arms crossed, to save children, women and men like you and me.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 25 n_passes 30
# Topic 21 terms:
#   refugee: 0.0361
#   border: 0.0351
#   migration: 0.0266
#   crisis: 0.0185
#   migrant: 0.0176
#   asylum: 0.0167
#   immigration: 0.0098
#   schengen: 0.0095
#   problem: 0.0084
#   external: 0.0083
# Number of speeches in topic 21 (['refugee', 'border', 'migration']) with prob >= 0.3): 8003
# Top speeches for topic 21 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.9771:
# I voted in favour of the report, which signals another call on Member States to
# uphold their responsibility and show solidarity by taking part in relocation and
# resettlement measures. Countries on the periphery, such as Greece and Italy, are
# still struggling to respond to the thousands of refugees and asylum-seekers who
# are arriving. We believe that resettlement should not take place at the expense
# of relocation. Both are important instruments of solidarity. Relocation is a
# form of internal solidarity among Member States, while resettlement and
# humanitarian admission or other kinds of admission are forms of external
# solidarity with third countries hosting the majority of refugees.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 21 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.3000:
# Madam President, Commissioner Johansson, in a plenary session so full of
# extremely sensitive issues, this European Parliament is once again addressing
# the rights of minors and particularly the problem of missing children.
# Appalling. The figures are truly overwhelming. The only known record —a 2013
# report— indicates that at least 250,000 reported minors are missing in the
# European Union, and they indeed call for coordinated action, contact points, and
# police and judicial cooperation. All proposals you may put on the table will be
# supported by this European Parliament, which shows its greatest solidarity when
# it comes to vulnerable unaccompanied minors. You have shown in those figures,
# which are also certainly shocking, that disappearances are recorded in conflicts
# taking place on our very borders and, therefore, impacting all Member States.
# Nearly 30,000 unaccompanied minors have entered from Ukraine, therefore
# demanding attention to their vulnerability as victims of violence, abuse, labour
# or sexual exploitation, or human trafficking networks. Therefore, there is not a
# second to lose. Commissioner Johansson, you have our full support for all
# measures you may adopt for that European register of missing persons and,
# particularly, of missing children.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 30 n_passes 5
# Topic 29 terms:
#   child: 0.0555
#   refugee: 0.0283
#   migration: 0.0181
#   asylum: 0.0171
#   migrant: 0.0168
#   border: 0.0141
#   human: 0.0093
#   problem: 0.0074
#   immigration: 0.0072
#   situation: 0.0070
# Number of speeches in topic 29 (['child', 'refugee', 'migration']) with prob >= 0.3): 7480
# Top speeches for topic 29 (['child', 'refugee', 'migration']):
#
# Speech 1 with topic probability 0.9839:
# In 2015, 1.83 million persons were found attempting to cross the EU’s external
# borders. 20% of the incoming migrants who arrived by sea were children. It must
# be acknowledged that the current system for asylum does not alleviate pressure
# on Member States with EU external borders. Change needs to be implemented in
# order to facilitate a fairer system which would include shared responsibility,
# with a central system for allocating asylum applicants. This would include a
# quota of refugees for each Member State. A binding and mandatory legislative
# approach is necessary for the relocation of asylum seekers. Currently only a
# small proportion of 106 000 refugees in Italy and Greece have been relocated. In
# the event of a returns procedure, migrants should only be returned if their
# safety would not be at risk.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 29 (['child', 'refugee', 'migration']):
#
# Speech 1 with topic probability 0.3000:
# Mr. President, Jordan and Lebanon have taken a humane and responsible approach
# to the refugee crisis. These two countries have taken in a total of more than
# four million refugees, which is more than a third, I repeat a third of their
# total population. Lebanon hosts more than one million Syrian refugees. There are
# 417,000 Syrian refugee children between the ages of three and fourteen living in
# Lebanon. It is estimated that almost half of them do not have access to any form
# of education. Between 2012 and 2015, the European Commission provided 269
# million for humanitarian aid in Lebanon in connection with the Syrian crisis. In
# 2016, the European Commission plans to allocate 87 million additional funds for
# humanitarian assistance. I appreciate this effort of the European Union.
# Education is the future, it means hope. Mothers of children who did not have a
# chance to get to Lebanon, however, ask themselves a different question every
# day. Will my baby be alive tomorrow? Will he survive another attack by Russian
# and Assad troops? I would like to remind you, ladies and gentlemen, that a
# trauma hospital, where there are also children patients, was bombed for the
# third time in Aleppo this Saturday. Jordan and Lebanon deserve not only our
# recognition, but also continued financial support within the framework of the
# European Union's regional fund and European humanitarian aid. The least we can
# do is make it easier for those who save lives for us. Let's stop the killing of
# Syrian children by the Assad-Russian alliance. Let's give Syrian children an
# education. This is the best weapon against war.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 30 n_passes 10
# Topic 19 terms:
#   refugee: 0.0348
#   border: 0.0301
#   migration: 0.0240
#   migrant: 0.0174
#   asylum: 0.0168
#   crisis: 0.0129
#   immigration: 0.0094
#   solidarity: 0.0083
#   external: 0.0080
#   mediterranean: 0.0079
# Number of speeches in topic 19 (['refugee', 'border', 'migration']) with prob >= 0.3): 8141
# Top speeches for topic 19 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.9869:
# I voted in favour of this report. Europe has been paralysed with regard to the
# migrant crisis. While we keep discussing possible solutions to the grave problem
# we face, it hardly ever comes to common action. However, even when we do decide
# on joint measures, we do not follow through on them. The Dublin Agreement and
# the relocation system have failed utterly, as the Member States have not
# committed to apply them. We must either effectively enforce the current
# measures, or introduce new ones. Either way, it is not a problem that can be
# solved by any Member State alone. It is a dilemma that must be dealt with by the
# European Union as a whole. It cannot be fixed by closing national borders, but
# only by guarding our common ones; those defined by Schengen. What we need to do
# is form a common border guard and coast guard and put a collective reception and
# relocation system in place. Furthermore, we must prompt Turkey to crack down on
# the criminals smuggling refugees to Europe under harsh circumstances and we must
# speak with African governments about returning economic migrants. However, what
# is most important is that Member States keep to it.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 19 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.3000:
# We often believe we can make up for our mistakes by repeating them. Operation
# Odyssey Dawn demonstrated the failure of the strategy of some states that
# claimed to cultivate democracy in the country simply by overthrowing Gaddafi
# with massive bombings. A state of law cannot arise spontaneously from chaos: 140
# tribes and clans that have always rivaled each other, 42 years of dictatorship,
# two parliaments, two governments, territorial militias of various natures... and
# the first victims are the Libyan citizens. The rest of the bill is paid by the
# Europeans who overlook the Mediterranean: 140,000 desperate migrants this year
# alone, 118,000 of whom are in Italy alone, 2,500 deaths since the beginning of
# 2014, 2,200 from June onwards. The EU continues to prevaricate. Europe must be
# truly united not only in diversity, but above all in these adversities. Let's
# prove it with concrete facts!
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 30 n_passes 20
# Topic 10 terms:
#   refugee: 0.0426
#   migration: 0.0306
#   border: 0.0243
#   migrant: 0.0205
#   asylum: 0.0193
#   crisis: 0.0169
#   immigration: 0.0108
#   problem: 0.0104
#   external: 0.0092
#   mediterranean: 0.0088
# Number of speeches in topic 10 (['refugee', 'migration', 'border']) with prob >= 0.3): 6970
# Top speeches for topic 10 (['refugee', 'migration', 'border']):
#
# Speech 1 with topic probability 0.9770:
# I voted in favour of the report, which signals another call on Member States to
# uphold their responsibility and show solidarity by taking part in relocation and
# resettlement measures. Countries on the periphery, such as Greece and Italy, are
# still struggling to respond to the thousands of refugees and asylum-seekers who
# are arriving. We believe that resettlement should not take place at the expense
# of relocation. Both are important instruments of solidarity. Relocation is a
# form of internal solidarity among Member States, while resettlement and
# humanitarian admission or other kinds of admission are forms of external
# solidarity with third countries hosting the majority of refugees.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 10 (['refugee', 'migration', 'border']):
#
# Speech 1 with topic probability 0.3001:
# I think that it is not necessary to underestimate the information of people who
# come to Europe as refugees, migrants, asylum seekers. They know they are no
# longer welcome here. That here, even today in the European Parliament, we
# discuss more about how to deter, contain, fence and reject them. Simply put -
# there are too many of them to be accepted broadly, according to the ethics and
# values we invoke in such speeches. We did not think about what would happen to
# us in Europe when we approved and participated in the wars that drove these
# people from their homes and prepared them to humiliate themselves today with
# their families on our roads and borders, they die on overturned boats. We did
# not consider this when we prioritized violent interventions over political and
# diplomatic solutions. We heard a lot of emotional speeches here today, a lot of
# anger at our helplessness. I will not participate in this myself. I would only
# emphasize that at this moment, all of us - High Representative Mogherini and all
# European governments - due to our own guilt and wrong decisions, must urgently
# and sincerely support the peace talks in Syria, which alone can restore
# confidence that the refugees will have somewhere to go return when the time
# comes. And then we will have to find political solutions also for other
# countries from which people are fleeing to Europe.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 30 n_passes 30
# Topic 26 terms:
#   refugee: 0.0393
#   border: 0.0373
#   migration: 0.0297
#   migrant: 0.0199
#   asylum: 0.0187
#   crisis: 0.0154
#   immigration: 0.0103
#   schengen: 0.0098
#   external: 0.0096
#   problem: 0.0086
# Number of speeches in topic 26 (['refugee', 'border', 'migration']) with prob >= 0.3): 7217
# Top speeches for topic 26 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.9770:
# I voted in favour of the report, which signals another call on Member States to
# uphold their responsibility and show solidarity by taking part in relocation and
# resettlement measures. Countries on the periphery, such as Greece and Italy, are
# still struggling to respond to the thousands of refugees and asylum-seekers who
# are arriving. We believe that resettlement should not take place at the expense
# of relocation. Both are important instruments of solidarity. Relocation is a
# form of internal solidarity among Member States, while resettlement and
# humanitarian admission or other kinds of admission are forms of external
# solidarity with third countries hosting the majority of refugees.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 26 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.3001:
# Madam President, many of us in this Assembly have long called for a real
# integration of migration into the Union's external policies and a real migration
# diplomacy. This is now done at the conceptual level. We therefore remain with
# the challenge of making this fundamental change in our approach a reality. In
# this regard, I would like to emphasize three elements. First, careful
# consideration is needed on financing. On the one hand, the good practices that
# already exist in the selected and so-called priority countries deserve to be
# better promoted; on the other hand, the question of the effectiveness of our
# financial instruments and, in particular, of the EDF must be asked. We must
# reduce the number of priorities to have a better impact. Second, yes, Africa is
# a key continent. In terms of migration management, support for border controls
# between African countries and the management of intra-African migration should
# be strengthened. Regarding the causes of migration, it is imperative to achieve
# results in development cooperation. This requires real effort and we are doing
# it: finding an approach and incentives that work and not neglecting other tools,
# economic and commercial, as levers for reforms linked to the rule of law and
# human rights. A general remark: pay attention to the message we send to all the
# other countries which are not a priority at the moment. And a particular
# question: what role for African regional organizations? Finally, two questions
# regarding the implementation of the action plan adopted in Valletta: what
# measures have been proposed to enhance the human and financial potential of the
# African diaspora in Europe? What about cooperation between sub-Saharan
# countries, southern Mediterranean countries and European countries?
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 40 n_passes 5
# Topic 7 terms:
#   refugee: 0.0346
#   border: 0.0297
#   migration: 0.0218
#   migrant: 0.0172
#   asylum: 0.0167
#   crisis: 0.0134
#   immigration: 0.0091
#   situation: 0.0083
#   problem: 0.0083
#   mediterranean: 0.0080
# Number of speeches in topic 7 (['refugee', 'border', 'migration']) with prob >= 0.3): 7985
# Top speeches for topic 7 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.9894:
# I supported the report with the proposal to create a European border and coast
# guard, as it is an important step to deal with the growing migration crisis and
# the threat of new terrorist acts on EU territory. The decision to create a
# European Border and Coast Guard Agency is important because it will ensure the
# protection of external borders and free and safe movement within the EU's
# internal borders. I support the mechanism of "shared responsibility" and
# collective action between the Member States and the EU, which is an essential
# contribution to increasing the solidarity and responsibility of national
# governments and European institutions and an important prerequisite for the
# protection of the EU's external borders and the management of migration flows.
# The facility will support frontline countries that are exposed to strong
# migratory pressures. Countries that are at the EU's external border but are not
# part of Schengen will be able to count on quick and adequate help to deal with
# sudden migration crises at the borders through deployed coast or maritime
# guards. The EGTC is a pan-European system that will ensure respect for the basic
# human rights of refugees seeking asylum, as well as assist Member States in
# returning migrants who have entered the EU illegally to their countries of
# origin, without interfering with decisions taken by national countries.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 7 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.3000:
# Mr President, we have heard much in this Chamber about how the terror attacks
# have nothing to do with the open-door policy EU leaders foisted upon Members,
# which saw migrants claim refugee status they were not entitled to. Daesh boasted
# they would flood our continent with jihad fighters, although Members here in the
# Chamber derided those of us who pointed this out. We know that two of the
# murderers involved in the Paris killings came to the continent via Greece, using
# false Syrian passports. What is this if it is not a direct link between
# uncontrolled immigration and terrorism? I reject this idea put forward by people
# like President Juncker that terrorism is a risk we must live with to uphold the
# EU’s ideals of freedom of movement. The migrant crisis has put the well-being of
# migrants ahead of the safety of its citizens by making us vulnerable to attack
# in our towns and cities. Come the UK’s referendum, voters must look at the
# negligence of the EU when it comes to securing our borders, and vote for
# independence.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 40 n_passes 10
# Topic 6 terms:
#   refugee: 0.0429
#   border: 0.0305
#   migration: 0.0289
#   migrant: 0.0209
#   asylum: 0.0198
#   crisis: 0.0163
#   immigration: 0.0106
#   solidarity: 0.0086
#   mediterranean: 0.0085
#   problem: 0.0082
# Number of speeches in topic 6 (['refugee', 'border', 'migration']) with prob >= 0.3): 6891
# Top speeches for topic 6 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.9768:
# I voted in favour of the report, which signals another call on Member States to
# uphold their responsibility and show solidarity by taking part in relocation and
# resettlement measures. Countries on the periphery, such as Greece and Italy, are
# still struggling to respond to the thousands of refugees and asylum-seekers who
# are arriving. We believe that resettlement should not take place at the expense
# of relocation. Both are important instruments of solidarity. Relocation is a
# form of internal solidarity among Member States, while resettlement and
# humanitarian admission or other kinds of admission are forms of external
# solidarity with third countries hosting the majority of refugees.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 6 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.3000:
# Vote in favor of draft amending budget no. 8/2015. This project, in fact, takes
# note of the necessary additional resources needed by Member States to address
# the refugee crisis, consequently reducing the contributions due by them to the
# Union budget by 9,403.4 million euros. Despite this need, the project does not
# fail to observe how the various financial commitments by the Member States have
# not yet been honored, for example those relating to the Trust Fund for Africa or
# the Trust Fund for Syria and for the agencies of UN refugee assistance. On the
# other hand, the project highlights how further financial efforts will be needed
# to provide humanitarian assistance along transit routes and to address the
# challenges associated with welcoming refugees.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 50 n_passes 5
# Topic 28 terms:
#   refugee: 0.0397
#   border: 0.0364
#   migration: 0.0261
#   migrant: 0.0208
#   asylum: 0.0206
#   crisis: 0.0109
#   immigration: 0.0099
#   external: 0.0089
#   schengen: 0.0085
#   human: 0.0079
# Number of speeches in topic 28 (['refugee', 'border', 'migration']) with prob >= 0.3): 6824
# Top speeches for topic 28 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.9796:
# Every Member State has a moral duty to help the refugees arriving from conflict
# areas like Syria or other war zones. We should help those who ask for our help.
# But I cannot support the mandatory introduction of quotas. If a refugee does not
# want to stay in one Member State, we should not attempt to force them to. Such a
# system would not work without the suspension of the Schengen Agreement and the
# freedom of movement that is fundamental to Europe today. It is normal that a
# refugee will continue to move towards their preferred objective, where they
# might already have family or work, and no quota will stop this desire. Each
# member states must be able to decide itself how many refugees to accept in its
# territory and accept those who truly desire their help. Therefore, I voted
# against this report.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 28 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.3000:
# I agree with the mid-term review of the Multiannual Financial Framework . In
# recent years it has become clear, above all, that the current flexibility
# provisions are essential for the European Union's ability to act. Especially in
# times of migration and refugee crises.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 50 n_passes 10
# Topic 40 terms:
#   refugee: 0.0477
#   migration: 0.0322
#   migrant: 0.0238
#   asylum: 0.0230
#   border: 0.0210
#   crisis: 0.0153
#   immigration: 0.0114
#   solidarity: 0.0105
#   mediterranean: 0.0097
#   situation: 0.0084
# Number of speeches in topic 40 (['refugee', 'migration', 'migrant']) with prob >= 0.3): 5858
# Top speeches for topic 40 (['refugee', 'migration', 'migrant']):
#
# Speech 1 with topic probability 0.9679:
# In today's vote, we decided whether Sweden should be granted an exemption from
# receiving its share of the refugees to be redistributed to Sweden from Italy and
# Greece. We chose to vote against for two main reasons. Sweden has been one of
# the EU countries that has pushed for a binding, solidary and fair distribution
# system and to bring about the temporary redistribution mechanism for 160,000
# refugees. The principle itself is based on the mechanism being binding and
# everyone receiving their share. Member States have two years to implement this
# redistribution. That Sweden requests a one-year exception in that situation
# reduces our credibility in the continued work of agreeing on a truly solidarity-
# based asylum policy. Since the ID checks were introduced, the number of refugees
# coming to Sweden has decreased drastically, which gives better conditions to
# receive refugees now. In light of the increasingly worsening situation for
# asylum seekers in Greece, we do not believe that there is any reason to grant an
# exception to any member state now. The focus must instead be on getting all
# member states to fulfill their obligation to participate in the relocation
# system. We hope that Sweden will continue to lead the way towards a fair asylum
# policy.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 40 (['refugee', 'migration', 'migrant']):
#
# Speech 1 with topic probability 0.3001:
# Madam President, ladies and gentlemen, a few days after the decision of the 27
# to indicate immigration and security as the first point, Austria already
# declares its intention to withdraw from the relocation and, immediately
# afterwards, Budapest clarifies that, should the commitment with Turkey fail,
# Hungary will stop migrants thanks to the wall and the new laws approved. At the
# same time, the Visegrád quartet denounces the blackmail of the European Union,
# what they call the blackmail of the European Union on migrants, and there is no
# mention of it here. As if everyone agrees with your immigration policy.
# Meanwhile - Frontex source - what emerges on the situation of trafficking from
# Libya? The High Commissioner or whoever replaces him tells us nothing. It
# emerges - Frontex source - that the activity of NGO ships has increased from 5
# to 40%, and at the end of 2016 the direct interventions of NGOs exceeded those
# of calls to the operations room of the military naval forces. And the report
# hypothesizes the existence - I repeat: Frontex report - of collusion with
# criminal ferrymen. The judiciary and police, the Italian SCO, are investigating
# this. And you don't tell us, you don't talk about it, as if it didn't exist. It
# is a very serious matter. So I ask for less hypocrisy and more truth about these
# traffickings. Enough with immigrant trafficking, enough with those who speculate
# on the plight of immigrants! You should talk to us about this, and be ashamed of
# your guilty silence.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 80 n_passes 5
# Topic 12 terms:
#   refugee: 0.0456
#   border: 0.0377
#   migration: 0.0287
#   migrant: 0.0221
#   asylum: 0.0217
#   crisis: 0.0140
#   immigration: 0.0102
#   mediterranean: 0.0095
#   external: 0.0087
#   problem: 0.0085
# Number of speeches in topic 12 (['refugee', 'border', 'migration']) with prob >= 0.3): 6248
# Top speeches for topic 12 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.9726:
# I support the Commission's proposal. Securing the EU's external border is a pan-
# European task. I think this proposal is a step in the right direction. Frontex
# must become a real border protection agency. It must not be the case that
# securing the EU's external border depends on whether an individual EU country is
# willing or able to do so. We have a humanitarian obligation to offer protection
# to people fleeing war and persecution. But this is only possible if we have real
# control over the EU's external border.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 12 (['refugee', 'border', 'migration']):
#
# Speech 1 with topic probability 0.3000:
# Madam President, my country is showing that ‘European solidarity’ are not empty
# words, but the way to face this, the worst refugee crisis since World War II. It
# is an existential crisis for the EU as the UN High Commissioner for Refugees put
# it, here today. Portugal received this week 64 refugees by chartered plane from
# Greece, assisting EASO to relocate human beings undergoing inhuman treatment at
# the closed borders of FYROM, after Austria and other neighbours ganged up to
# violate the Schengen system, international law, EU Council decisions and sheer
# decency. More refugees are expected later this week, thanks to the proactive
# response of the government of Portugal. But, what about other EU governments?
# Why are the European Commission and the European Council so prone to punishing
# Portugal and Greece for failing to meet deficit decimals and not acting against
# Hungary, Austria and other Members who gang up to bomb European solidarity and
# torture women and children who asked for protection in Europe? Could it be for
# the same reason that the European Council allowed itself to be blackmailed
# yesterday by President Erdoğan’s Turkey?
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 80 n_passes 10
# Topic 71 terms:
#   refugee: 0.0523
#   migration: 0.0381
#   migrant: 0.0293
#   asylum: 0.0276
#   border: 0.0242
#   crisis: 0.0154
#   immigration: 0.0138
#   frontex: 0.0100
#   mediterranean: 0.0099
#   solidarity: 0.0094
# Number of speeches in topic 71 (['refugee', 'migration', 'migrant']) with prob >= 0.3): 4736
# Top speeches for topic 71 (['refugee', 'migration', 'migrant']):
#
# Speech 1 with topic probability 0.9506:
# Given the current number of asylum seekers in Greece and the increasing number
# of asylum seekers arriving in Italy, I believe that there will remain a high
# demand for emergency relocation places.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 71 (['refugee', 'migration', 'migrant']):
#
# Speech 1 with topic probability 0.3000:
# Perhaps I am a windbag, but you are a dreamer, dear colleague. Honourable
# colleagues, the Africa strategy is an ideological, a neo-colonialist, an
# unrealistic project that will drag Europe into the abyss. Africa's core problem
# – it was not even remotely addressed. Not a single word about Africa's massive
# overpopulation in the entire document! Europe's demographic problem is not to be
# solved through adequate family policy, as is the case, for example, in much-
# criticised Hungary – no, illegal immigration is to be legalised and the problem
# solved with the mass immigration of culturally alien and mostly very unqualified
# migrants. Germany can tell quite a story about how well that works since 2015.
# This is immigration into the social welfare systems without any benefit for our
# society and not to the benefit of these migrants either. The migrants send ample
# money back to Africa, which means that the problem of overpopulation is not
# solved, but only massively exacerbated. Was the European citizen asked if they
# support this madness? No, of course not. That is democracy à la EU. We reject
# that. One thing is clear, however: You cannot help Africa by destroying your own
# continent.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 100 n_passes 5
# Topic 43 terms:
#   refugee: 0.0486
#   migration: 0.0358
#   migrant: 0.0299
#   asylum: 0.0284
#   border: 0.0268
#   immigration: 0.0131
#   frontex: 0.0095
#   illegal: 0.0092
#   crisis: 0.0090
#   external: 0.0081
# Number of speeches in topic 43 (['refugee', 'migration', 'migrant']) with prob >= 0.3): 4651
# Top speeches for topic 43 (['refugee', 'migration', 'migrant']):
#
# Speech 1 with topic probability 0.9505:
# Given the current number of asylum seekers in Greece and the increasing number
# of asylum seekers arriving in Italy, I believe that there will remain a high
# demand for emergency relocation places.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 43 (['refugee', 'migration', 'migrant']):
#
# Speech 1 with topic probability 0.3000:
# I agree, colleague: poverty is at the center and also the inability to deal with
# migration. There are proposals, put forward by the left, there are also
# proposals regarding the integration of migrants and growth based on ecology. It
# is a proposal that generally remains in the minority but this does not mean that
# it does not exist as a proposal.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================
# n_topics: 100 n_passes 10
# Topic 78 terms:
#   refugee: 0.0549
#   migration: 0.0413
#   migrant: 0.0311
#   asylum: 0.0292
#   immigration: 0.0144
#   solidarity: 0.0114
#   mediterranean: 0.0109
#   frontex: 0.0105
#   crisis: 0.0097
#   illegal: 0.0095
# Number of speeches in topic 78 (['refugee', 'migration', 'migrant']) with prob >= 0.3): 4226
# Top speeches for topic 78 (['refugee', 'migration', 'migrant']):
#
# Speech 1 with topic probability 0.9505:
# Given the current number of asylum seekers in Greece and the increasing number
# of asylum seekers arriving in Italy, I believe that there will remain a high
# demand for emergency relocation places.
#
# --------------------------------------------------------------------------------
#
# Just passing speeches for topic 78 (['refugee', 'migration', 'migrant']):
#
# Speech 1 with topic probability 0.3000:
# I voted against this report, because it gives an inappropriate role to migrants.
#
# --------------------------------------------------------------------------------
#
# ======================================================================================================================================================

# %% [markdown]
# we considered more closely
# 20, 20 (7985)
# 25, 10 (6959)
# 25, 20 (7794) -
# 25, 30 (8003) - problem: Topic 1: ukraine, russia, turkey, russian, war
# 30, 10 (8141) - the best
# 30, 20 (6970)
# 30, 30 (7217)
# 40, 5 (7985)
# 40, 10 (6891)

# %%
stats = json.load(open("data/lda/screens/comparison.json"))
stats = pd.DataFrame(stats) 

import matplotlib.pyplot as plt

# %%
stats["coherence"] = stats["coherence"].astype(float)
stats["highest_prob"] = stats["highest_prob"].astype(float)

# %%
stats = stats.groupby("n_topics").mean()

# %%
stats
# Out:
#            n_passes  coherence  highest_prob   top_pos  n_relevant_topics
# n_topics
# 10         5.000000   0.472070      0.007199  8.000000                1.0
# 20         5.000000   0.534286      0.016546  2.000000                1.0
# 25         7.500000   0.554377      0.021750  2.500000                1.0
# 30        11.666667   0.552823      0.025351  2.333333                1.0
# 40         7.500000   0.563017      0.025353  2.000000                1.0
# 50         7.500000   0.560327      0.029128  1.500000                1.0
# 60         7.500000   0.550996      0.024583  2.000000                2.0
# 80         7.500000   0.526664      0.033428  1.500000                1.0
# 100        7.500000   0.522345      0.038523  1.000000                1.0

# %%
plt.figure()
plt.scatter(stats.index, stats["coherence"], marker="x", label="coherence")
plt.title("Coherences")
plt.figure()
plt.scatter(stats.index, stats["top_pos"], marker="x", label="coherence")
plt.title("Top positions")
plt.figure()
plt.scatter(stats.index, stats["highest_prob"], marker="x", label="coherence")
plt.title("Max probs")
# Out:
# Text(0.5, 1.0, 'Max probs')

# %%
n_speeches_n_passes = {}
for (n_topics, n_passes) in dfs_migration.keys(): 
    n_speeches = len(dfs_migration[(n_topics, n_passes)])
    if n_passes not in n_speeches_n_passes: 
        n_speeches_n_passes[n_passes] = []
    
    n_speeches_n_passes[n_passes].append((n_topics, n_speeches))

# %%
plt.figure()
for n_passes, values in n_speeches_n_passes.items():
    x, y = zip(*values)
    plt.scatter(x, y, label=f"{n_passes} passes", marker="o")
plt.legend()
plt.title("Number of speeches per n_topics")
# Out:
# Text(0.5, 1.0, 'Number of speeches per n_topics')

# %%
final_config = (30, 10)

# %%
print_topics(models[final_config], final_config[0])
# Out:
# Topic 0: security, united, common, challenge, world
# Topic 1: want, think, commissioner, say, know
# Topic 2: budget, fund, financial, euro, billion
# Topic 3: worker, transport, sector, fund, globalization
# Topic 4: fishing, fishery, sea, water, fish
# Topic 5: financial, committee, agency, budget, discharge
# Topic 6: development, economic, strategy, growth, investment
# Topic 7: human, freedom, democracy, political, medium
# Topic 8: law, rule, government, democracy, treaty
# Topic 9: tax, company, fraud, money, evasion
# Topic 10: woman, gender, equality, man, violence
# Topic 11: attack, world, today, victim, terrorist
# Topic 12: health, substance, china, scientific, modify
# Topic 13: bank, crisis, economic, unemployment, investment
# Topic 14: energy, climate, emission, change, gas
# Topic 15: agreement, trade, council, protocol, regulation
# Topic 16: conflict, peace, humanitarian, international, situation
# Topic 17: education, cultural, human, young, training
# Topic 18: turkey, germany, minister, german, want
# Topic 19: refugee, border, migration, migrant, asylum
# Topic 20: resolution, group, text, amendment, proposal
# Topic 21: ukraine, russia, russian, moldova, war
# Topic 22: social, poverty, worker, employment, labor
# Topic 23: datum, cooperation, information, protection, crime
# Topic 24: product, food, agricultural, animal, farmer
# Topic 25: political, election, process, reform, immunity
# Topic 26: market, regulation, service, single, digital
# Topic 27: health, disaster, cause, solidarity, medicine
# Topic 28: sanction, death, penalty, regime, human
# Topic 29: child, convention, international, family, accession

# %%
topics_keywords = find_topic_id("migration", models[final_config], final_config[0]) 
if isinstance(topics_keywords, int): 
    explore_topic_id(topics_keywords, models[final_config], dfs[final_config], f"{final_config[0]} topics; {final_config[1]} passes", speech_number=0)
# Out:
# Topic 19 terms:
#   refugee: 0.0348
#   border: 0.0301
#   migration: 0.0240
#   migrant: 0.0174
#   asylum: 0.0168
#   crisis: 0.0129
#   immigration: 0.0094
#   solidarity: 0.0083
#   external: 0.0080
#   mediterranean: 0.0079
# Number of speeches in topic 19 (['refugee', 'border', 'migration']) with prob >= 0.3): 8141
# Top speeches for topic 19 (['refugee', 'border', 'migration']):
#
# Just passing speeches for topic 19 (['refugee', 'border', 'migration']):

# %%
dfs[final_config].to_csv("data/lda/df_30topics10passes.parquet")
